# %% [markdown]
# # ACCESS-S2-ETBF-var-export

# %% [markdown]
# **Date:** <br>
# 17 August 2021 <br>
# **Background:** <br>
# Export ETBF ocean variables <br>
# **Author(s):**<br>
# Thomas Moore<br>

# %%
Author1 = {"name": "Thomas Moore", "affiliation": "CSIRO", "email": "thomas.moore@csiro.au", "orcid": "0000-0003-3930-1946"}

# %%
import xarray as xr
from dask_jobqueue import PBSCluster
from dask.distributed import Client
import numpy as np
import xrft
import xesmf as xe
import scipy
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import os
import re
import cartopy.crs as ccrs
# %config Completer.use_jedi = False

# %%
# supress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Spin up cluster with `dask-jobqueue`
# *----*<br>

# %% [markdown]
# ### Specs for an individual worker

# %%
walltime = '02:00:00'
cores = 2
memory = '8GB'

cluster = PBSCluster(processes = 1, walltime=str(walltime), cores=cores, memory=str(memory),
                     job_extra=['-P xv83','-l ncpus='+str(cores),'-l mem='+str(memory),
                                '-l storage=gdata/v14+scratch/v14+gdata/lp01+scratch/lp01+scratch/ux06+gdata/rr3+gdata/al33+gdata/zv2+gdata/ux62'],
                     header_skip=["select"])

# %% [markdown]
# ### Scale up to n workers

# %%
cluster.scale(jobs=8)

# %%
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://10.6.54.51:35501' processes=0 threads=0, memory=0 B>

# %%
# define preprocess drop function - this unfortunately removes useful information like areau that's missing from 2015 files
def drop_not_in_2015(ds):
    if 'latu_bounds' in ds.data_vars:
        ds = ds.drop(['latu_bounds'])
    if 'lonu_bounds' in ds.data_vars:
        ds = ds.drop(['lonu_bounds'])
    if 'latv_bounds' in ds.data_vars:
        ds = ds.drop(['latv_bounds'])
    if 'lonv_bounds' in ds.data_vars:
        ds = ds.drop(['lonv_bounds'])
    if 'latt_bounds' in ds.data_vars:
        ds = ds.drop(['latt_bounds'])
    if 'lont_bounds' in ds.data_vars:
        ds = ds.drop(['lont_bounds'])    
    if 'depthu_bounds' in ds.data_vars:
        ds = ds.drop(['depthu_bounds'])
    if 'areau' in ds.data_vars:
        ds = ds.drop(['areau'])
    if 'depthv_bounds' in ds.data_vars:
        ds = ds.drop(['depthv_bounds'])
    if 'areav' in ds.data_vars:
        ds = ds.drop(['areav'])
    if 'deptht_bounds' in ds.data_vars:
        ds = ds.drop(['deptht_bounds'])
    if 'areat' in ds.data_vars:
        ds = ds.drop(['areat'])        
    return ds

# %% [markdown]
# # SST

# %% [markdown]
# ### load the whole SST timeseries using `drop` preproccessor

# %%
# %%time
ds_SST_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/sst/mo_sst_*.nc',parallel=True,preprocess=drop_not_in_2015)
ds_SST_1981_2018
# Out:
# CPU times: user 3.54 s, sys: 1.31 s, total: 4.85 s
# Wall time: 15.9 s
# <xarray.Dataset>
# Dimensions:            (deptht: 1, tbnds: 2, time_counter: 456, x: 1442, y: 1021)
# Coordinates:
#   * deptht             (deptht) float32 0.5058
#     nav_lat            (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#     nav_lon            (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#   * time_counter       (time_counter) datetime64[ns] 1981-01-16T12:00:00 ... ...
# Dimensions without coordinates: tbnds, x, y
# Data variables:
#     sst                (time_counter, deptht, y, x) float32 dask.array<chunksize=(12, 1, 1021, 1442), meta=np.ndarray>
#     time_counter_bnds  (time_counter, tbnds) datetime64[ns] dask.array<chunksize=(12, 2), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     production:   An IPSL model
#     TimeStamp:    12/09/2018 08:38:02 -0000
#     NCO:          netCDF Operators version 4.7.7 (Homepage = http://nco.sf.ne...
#     history:      Tue Apr  2 17:32:22 2019: ncatted -a history,global,d,, mo_...

# %% [markdown]
# ## add back in key metadata

# %%
areat = (xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/sst/mo_sst_2016.nc',parallel=True)).areat.to_dataset()
areau = (xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/u/mo_u_2016.nc',parallel=True)).areau.to_dataset()
areav = (xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/v/mo_v_2016.nc',parallel=True)).areav.to_dataset()

# %%
areat
# Out:
# <xarray.Dataset>
# Dimensions:  (x: 1442, y: 1021)
# Coordinates:
#     nav_lat  (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#     nav_lon  (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
# Dimensions without coordinates: x, y
# Data variables:
#     areat    (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>

# %%
ds_SST_1981_2018 = xr.combine_by_coords([ds_SST_1981_2018,areat])
ds_SST_1981_2018
# Out:
# <xarray.Dataset>
# Dimensions:            (deptht: 1, tbnds: 2, time_counter: 456, x: 1442, y: 1021)
# Coordinates:
#     nav_lat            (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#     nav_lon            (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#   * deptht             (deptht) float32 0.5058
#   * time_counter       (time_counter) datetime64[ns] 1981-01-16T12:00:00 ... ...
# Dimensions without coordinates: tbnds, x, y
# Data variables:
#     areat              (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#     sst                (time_counter, deptht, y, x) float32 dask.array<chunksize=(12, 1, 1021, 1442), meta=np.ndarray>
#     time_counter_bnds  (time_counter, tbnds) datetime64[ns] dask.array<chunksize=(12, 2), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     production:   An IPSL model
#     TimeStamp:    12/09/2018 08:38:02 -0000
#     NCO:          netCDF Operators version 4.7.7 (Homepage = http://nco.sf.ne...
#     history:      Tue Apr  2 17:32:22 2019: ncatted -a history,global,d,, mo_...

# %% [markdown]
# # Deal with the same depth coordinates given two different names & rename time

# %%
ds_SST_1981_2018 = ds_SST_1981_2018.rename({'deptht':'depth','time_counter':'time'})

# %%
ds_SST_1981_2018.sst.isel(time=0).plot()

# %%
print(ds_SST_1981_2018.nav_lat.attrs)
print(ds_SST_1981_2018.nav_lon.attrs)
# Out:
# {'standard_name': 'latitude', 'units': 'degrees_north', 'valid_min': -77.010475, 'valid_max': 89.94787, 'long_name': 'Latitude', 'nav_model': 'Default grid', 'bounds': 'latt_bounds'}
# {'standard_name': 'longitude', 'units': 'degrees_east', 'valid_min': -180.0, 'valid_max': 180.0, 'long_name': 'Longitude', 'nav_model': 'Default grid', 'bounds': 'lont_bounds'}

# %% [markdown]
# # Deal with curvilinear grid

# %%
nav_lon = ds_SST_1981_2018['nav_lon'].compute()
nav_lat = ds_SST_1981_2018['nav_lat'].compute()

# %%
plt.scatter(nav_lon, nav_lat, s=0.01)  # plot grid locations
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.ylim([-80, 90])
plt.xlabel('lon')
plt.ylabel('lat')
plt.title('ACCESS-S2 Curvilinear grid')
# Out:
# Text(0.5, 1.0, 'ACCESS-S2 Curvilinear grid')

# %%
ds_SST_1981_2018 = ds_SST_1981_2018.rename({'nav_lon': 'lon', 'nav_lat': 'lat'})
ds_SST_1981_2018
# Out:
# <xarray.Dataset>
# Dimensions:            (depth: 1, tbnds: 2, time: 456, x: 1442, y: 1021)
# Coordinates:
#     lat                (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#     lon                (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#   * depth              (depth) float32 0.5058
#   * time               (time) datetime64[ns] 1981-01-16T12:00:00 ... 2018-12-...
# Dimensions without coordinates: tbnds, x, y
# Data variables:
#     areat              (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#     sst                (time, depth, y, x) float32 dask.array<chunksize=(12, 1, 1021, 1442), meta=np.ndarray>
#     time_counter_bnds  (time, tbnds) datetime64[ns] dask.array<chunksize=(12, 2), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     production:   An IPSL model
#     TimeStamp:    12/09/2018 08:38:02 -0000
#     NCO:          netCDF Operators version 4.7.7 (Homepage = http://nco.sf.ne...
#     history:      Tue Apr  2 17:32:22 2019: ncatted -a history,global,d,, mo_...

# %%
ds_out = xe.util.grid_global(1, 1)
ds_out
# Out:
# <xarray.Dataset>
# Dimensions:  (x: 360, x_b: 361, y: 180, y_b: 181)
# Coordinates:
#     lon      (y, x) float64 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
#     lat      (y, x) float64 -89.5 -89.5 -89.5 -89.5 ... 89.5 89.5 89.5 89.5
#     lon_b    (y_b, x_b) int64 -180 -179 -178 -177 -176 ... 176 177 178 179 180
#     lat_b    (y_b, x_b) int64 -90 -90 -90 -90 -90 -90 -90 ... 90 90 90 90 90 90
# Dimensions without coordinates: x, x_b, y, y_b
# Data variables:
#     *empty*

# %%
da
# Out:
# <xarray.DataArray 'sst' (time: 456, depth: 1, y: 1021, x: 1442)>
# dask.array<concatenate, shape=(456, 1, 1021, 1442), dtype=float32, chunksize=(12, 1, 1021, 1442), chunktype=numpy.ndarray>
# Coordinates:
#     lat      (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#     lon      (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#   * depth    (depth) float32 0.5058
#   * time     (time) datetime64[ns] 1981-01-16T12:00:00 ... 2018-12-16T12:00:00
# Dimensions without coordinates: y, x
# Attributes:
#     units:               degC
#     standard_name:       sea_water_potential_temperature
#     long_name:           Temperature
#     online_operation:    ave(X)
#     interval_operation:  1350.0
#     interval_write:      86400.0
#     cell_measures:       area: areat
#     cell_methods:        time_counter: mean

# %%
da = ds_SST_1981_2018.sst
regridder = xe.Regridder(da, ds_out, 'bilinear')
da_out = regridder(da)
# Out:
# Create weight file: bilinear_1021x1442_180x360.nc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a31c936a0511> in <module>
#       1 da = ds_SST_1981_2018.sst
# ----> 2 regridder = xe.Regridder(da, ds_out, 'bilinear')
#       3 da_out = regridder(da)
#
# /g/data/v14/tm4888/miniconda3/envs/pangeo_hpc_operational/lib/python3.8/site-packages/xesmf/frontend.py in __init__(self, ds_in, ds_out, method, periodic, filename, reuse_weights, ignore_degenerate, locstream_in, locstream_out)
#     233
#     234         # get weight matrix
# --> 235         self._write_weight_file()
#     236         self.weights = read_weights(self.filename, self.n_in, self.n_out)
#     237
#
# /g/data/v14/tm4888/miniconda3/envs/pangeo_hpc_operational/lib/python3.8/site-packages/xesmf/frontend.py in _write_weight_file(self)
#     275             print('Create weight file: {}'.format(self.filename))
#     276
# --> 277         regrid = esmf_regrid_build(self._grid_in, self._grid_out, self.method,
#     278                                    filename=self.filename,
#     279                                    ignore_degenerate=self.ignore_degenerate)
#
# /g/data/v14/tm4888/miniconda3/envs/pangeo_hpc_operational/lib/python3.8/site-packages/xesmf/backend.py in esmf_regrid_build(sourcegrid, destgrid, method, filename, extra_dims, ignore_degenerate)
#     275     # Must set unmapped_action to IGNORE, otherwise the function will fail,
#     276     # if the destination grid is larger than the source grid.
# --> 277     regrid = ESMF.Regrid(sourcefield, destfield, filename=filename,
#     278                          regrid_method=esmf_regrid_method,
#     279                          unmapped_action=ESMF.UnmappedAction.IGNORE,
#
# /g/data/v14/tm4888/miniconda3/envs/pangeo_hpc_operational/lib/python3.8/site-packages/ESMF/util/decorators.py in new_func(*args, **kwargs)
#      62
#      63         esmp = esmpymanager.Manager(debug = False)
# ---> 64         return func(*args, **kwargs)
#      65     return new_func
#      66
#
# /g/data/v14/tm4888/miniconda3/envs/pangeo_hpc_operational/lib/python3.8/site-packages/ESMF/api/regrid.py in __init__(self, srcfield, dstfield, filename, rh_filename, src_mask_values, dst_mask_values, regrid_method, pole_method, regrid_pole_npoints, line_type, norm_type, extrap_method, extrap_num_src_pnts, extrap_dist_exponent, unmapped_action, ignore_degenerate, create_rh, src_frac_field, dst_frac_field, factors)
#     136                 raise ImportError(msg)
#     137
# --> 138             self._routehandle = ESMP_FieldRegridStoreFile(
#     139                 srcfield,
#     140                 dstfield,
#
# /g/data/v14/tm4888/miniconda3/envs/pangeo_hpc_operational/lib/python3.8/site-packages/ESMF/util/decorators.py in new_func(*args, **kwargs)
#      50             lineno=func.__code__.co_firstlineno + 1,
#      51         )
# ---> 52         return func(*args, **kwargs)
#      53     return new_func
#      54
#
# /g/data/v14/tm4888/miniconda3/envs/pangeo_hpc_operational/lib/python3.8/site-packages/ESMF/interface/cbindings.py in ESMP_FieldRegridStoreFile(srcField, dstField, filename, srcMaskValues, dstMaskValues, regridmethod, polemethod, regridPoleNPnts, lineType, normType, unmappedaction, ignoreDegenerate, createRH, srcFracField, dstFracField)
#    2203                                      dstFracField)
#    2204     if rc != constants._ESMP_SUCCESS:
# -> 2205         raise ValueError('ESMC_FieldRegridStoreFile() failed with rc = '+str(rc)+
#    2206                         '.    '+constants._errmsg)
#    2207     return routehandle
#
# ValueError: ESMC_FieldRegridStoreFile() failed with rc = 506.    Please check the log files (named "*ESMF_LogFile").

# %% [markdown]
# # Check if zarr collections exist in `/g/data/v14/tm4888/data/ACCESS-S2/` and skip arrows if you can
# # $\Downarrow$

# %% [markdown]
# # ACCESS-S2 ocean reanalysis (RA) 1981 - 2018

# %% [markdown]
# # load U & V S2_RA

# %%
# %%time
# define preprocess drop function - this unfortunately removes useful information like areau that's missing from 2015 files
def drop_not_in_2015(ds):
    if 'latu_bounds' in ds.data_vars:
        ds = ds.drop(['latu_bounds'])
    if 'lonu_bounds' in ds.data_vars:
        ds = ds.drop(['lonu_bounds'])
    if 'latv_bounds' in ds.data_vars:
        ds = ds.drop(['latv_bounds'])
    if 'lonv_bounds' in ds.data_vars:
        ds = ds.drop(['lonv_bounds'])
    if 'depthu_bounds' in ds.data_vars:
        ds = ds.drop(['depthu_bounds'])
    if 'areau' in ds.data_vars:
        ds = ds.drop(['areau'])
    if 'depthv_bounds' in ds.data_vars:
        ds = ds.drop(['depthv_bounds'])
    if 'areav' in ds.data_vars:
        ds = ds.drop(['areav'])    
    return ds
ds_u_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/u/mo_u_*.nc',parallel=True,preprocess=drop_not_in_2015)
ds_u_1981_2018
# Out:
# CPU times: user 3.91 s, sys: 1.24 s, total: 5.16 s
# Wall time: 20.2 s
# <xarray.Dataset>
# Dimensions:            (depthu: 75, tbnds: 2, time_counter: 456, x: 1442, y: 1021)
# Coordinates:
#   * depthu             (depthu) float32 0.5058 1.556 ... 5.698e+03 5.902e+03
#     nav_lat            (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#     nav_lon            (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#   * time_counter       (time_counter) datetime64[ns] 1981-01-16T12:00:00 ... ...
# Dimensions without coordinates: tbnds, x, y
# Data variables:
#     time_counter_bnds  (time_counter, tbnds) datetime64[ns] dask.array<chunksize=(12, 2), meta=np.ndarray>
#     u                  (time_counter, depthu, y, x) float32 dask.array<chunksize=(12, 75, 1021, 1442), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     production:   An IPSL model
#     TimeStamp:    12/09/2018 08:37:54 -0000
#     NCO:          netCDF Operators version 4.7.7 (Homepage = http://nco.sf.ne...
#     history:      Tue Apr  2 18:39:39 2019: ncatted -a history,global,d,, mo_...

# %%
# %%time
# define preprocess drop function - this unfortunately removes useful information like areau that's missing from 2015 files
def drop_not_in_2015(ds):
    if 'latu_bounds' in ds.data_vars:
        ds = ds.drop(['latu_bounds'])
    if 'lonu_bounds' in ds.data_vars:
        ds = ds.drop(['lonu_bounds'])
    if 'latv_bounds' in ds.data_vars:
        ds = ds.drop(['latv_bounds'])
    if 'lonv_bounds' in ds.data_vars:
        ds = ds.drop(['lonv_bounds'])
    if 'depthu_bounds' in ds.data_vars:
        ds = ds.drop(['depthu_bounds'])
    if 'areau' in ds.data_vars:
        ds = ds.drop(['areau'])
    if 'depthv_bounds' in ds.data_vars:
        ds = ds.drop(['depthv_bounds'])
    if 'areav' in ds.data_vars:
        ds = ds.drop(['areav'])    
    return ds
ds_v_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/v/mo_v_*.nc',parallel=True,preprocess=drop_not_in_2015)
ds_v_1981_2018
# Out:
# CPU times: user 3.8 s, sys: 1.21 s, total: 5.01 s
# Wall time: 19.1 s
# <xarray.Dataset>
# Dimensions:            (depthv: 75, tbnds: 2, time_counter: 456, x: 1442, y: 1021)
# Coordinates:
#   * depthv             (depthv) float32 0.5058 1.556 ... 5.698e+03 5.902e+03
#     nav_lat            (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#     nav_lon            (y, x) float32 dask.array<chunksize=(1021, 1442), meta=np.ndarray>
#   * time_counter       (time_counter) datetime64[ns] 1981-01-16T12:00:00 ... ...
# Dimensions without coordinates: tbnds, x, y
# Data variables:
#     time_counter_bnds  (time_counter, tbnds) datetime64[ns] dask.array<chunksize=(12, 2), meta=np.ndarray>
#     v                  (time_counter, depthv, y, x) float32 dask.array<chunksize=(12, 75, 1021, 1442), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     production:   An IPSL model
#     TimeStamp:    12/09/2018 08:37:34 -0000
#     NCO:          netCDF Operators version 4.7.7 (Homepage = http://nco.sf.ne...
#     history:      Tue Apr  2 18:08:10 2019: ncatted -a history,global,d,, mo_...

# %% [markdown]
# # Deal with the same depth coordinates given two different names & rename time

# %%
ds_u_1981_2018 = ds_u_1981_2018.rename({'depthu':'depth','time_counter':'time'})
ds_v_1981_2018 = ds_v_1981_2018.rename({'depthv':'depth','time_counter':'time'})

# %% [markdown]
# # rechunk the data to shrink chunks from 5GB to 100MB
# **could use `rechunker` here?**

# %%
u = ds_u_1981_2018.chunk({'time':456,'depth':1,'x':250,'y':250})
v = ds_v_1981_2018.chunk({'time':456,'depth':1,'x':250,'y':250})

# %% [markdown]
# # write U & V to zarr collections

# %%
# %%time
# !rm -rf /g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.u.zarr
u.to_zarr('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.u.zarr',consolidated=True)

# %%
# %%time
# !rm -rf /g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.v.zarr
v.to_zarr('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.v.zarr',consolidated=True)

# %% [markdown]
# # $\Downarrow$
# # CAN SKIP TO THIS STEP IF U & V `ZARR` FILES ARE WRITTEN AND AVAILABLE
# hard part for u & v done above

# %%
u = xr.open_zarr('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.u.zarr',consolidated=True)
v = xr.open_zarr('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.v.zarr',consolidated=True)

# %%
def calc_EKE(u, v, time_name = 'time'):
    '''
    Author1 = {"name": "Thomas Moore", "affiliation": "CSIRO", "email": "thomas.moore@csiro.au", "orcid": "0000-0003-3930-1946"}
    u,v are x and y currents as an xarray data array
    '''
    u_mean = u.mean(time_name)
    v_mean = v.mean(time_name)
    MKE = 0.5*(u_mean**2 + v_mean**2).rename('MKE') # currents
    EKE = ( 0.5 * ((u-u_mean)**2 + (v-v_mean)**2) ).rename('EKE') # eddies
    return EKE, MKE

# %%
u_da = u.u
v_da = v.v

# %%
# %%time
[EKE, MKE] = calc_EKE(u_da, v_da, time_name='time')
# Out:
# CPU times: user 290 ms, sys: 12.5 ms, total: 302 ms
# Wall time: 634 ms

# %%
KE = xr.merge([EKE,MKE])

# %%
KE
# Out:
# <xarray.Dataset>
# Dimensions:  (depth: 75, time: 455, x: 1442, y: 1021)
# Coordinates:
#   * time     (time) datetime64[ns] 1981-01-16T12:00:00 ... 2018-12-16T12:00:00
#   * depth    (depth) float32 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
# Dimensions without coordinates: x, y
# Data variables:
#     EKE      (time, depth, y, x) float32 dask.array<chunksize=(455, 1, 250, 250), meta=np.ndarray>
#     MKE      (depth, y, x) float32 dask.array<chunksize=(1, 250, 250), meta=np.ndarray>

# %%
# %%time
# !rm -rf /g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.EKE.zarr
KE.to_zarr('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.EKE.zarr',consolidated=True)
# Out:
# CPU times: user 46.5 s, sys: 2.4 s, total: 48.9 s
# Wall time: 2min 4s

# %% [markdown]
# # $\Downarrow$
# # CAN SKIP TO THIS STEP IF EKE `ZARR` FILE IS WRITTEN AND AVAILABLE
# hard part for u & v & EKE & MKE done above

# %%
KE = xr.open_zarr('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.EKE.zarr',consolidated=True)

# %%
EKE_mean = KE.EKE.mean('time').compute()

# %% [markdown]
# # reduce dataset to surface only

# %%
KE_surface = KE.isel(depth=0).compute()

# %%
KE_surface.sel(x=slice(250,450),y=slice(250,450)).mean('time').EKE.plot(vmax=.05)

# %% [markdown]
# # write file to netcdf

# %%
# %%time
KE_surface.to_netcdf('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.EKE_surface.nc',mode='w')
# Out:
# CPU times: user 99.7 ms, sys: 1.82 s, total: 1.92 s
# Wall time: 3.3 s

# %%
KE = KE.persist()

# %%
# %%time
KE.to_netcdf('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.EKE.nc',mode='w')

# %% [markdown]
# # $ The\ End$

# %% [markdown]
# # Break glass in case of emergency
# # $\Downarrow$

# %%
client.restart()
# Out:
# <Client: 'tcp://10.6.79.72:34869' processes=16 threads=192, memory=715.20 GiB>

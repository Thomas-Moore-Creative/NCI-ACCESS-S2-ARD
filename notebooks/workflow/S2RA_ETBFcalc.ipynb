# %% [markdown]
# # S2RA_ETBFcalc

# %% [markdown]
# **Date:** <br>
# 23 February 2022 <br>
# **Background:** <br>
# Issue -  <br>
# **Author(s):**<br>
# Thomas Moore<br>

# %% [markdown]
# ### OOD documentation
# https://opus.nci.org.au/display/DAE/Setting+up+a+Dask+Cluster+on+OOD

# %%
Author1 = {"name": "Thomas Moore", "affiliation": "CSIRO", "email": "thomas.moore@csiro.au", "orcid": "0000-0003-3930-1946"}

# %%
import xarray as xr
import numpy as np
import xrft
import xesmf as xe
import scipy
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import os
import re
import cartopy.crs as ccrs
import proplot as pplt
from rechunker import rechunk
# %config Completer.use_jedi = False

# %% [markdown]
# ## import helper

# %%
import importlib.util
spec = importlib.util.spec_from_file_location("helper", "/g/data/v14/tm4888/code/helper-py/helper_tools.py")
helper = importlib.util.module_from_spec(spec)
spec.loader.exec_module(helper)

# %% [markdown]
# ## OOD cluster

# %% [raw]
# from dask.distributed import Client,Scheduler
# from dask_jobqueue import SLURMCluster
# cluster = SLURMCluster(cores=2,processes=1,memory="47GB",walltime='02:00:00')
# client = Client(cluster)
# cluster.scale(cores=24)

# %%
from dask.distributed import Client,Scheduler
from dask_jobqueue import SLURMCluster
cluster = SLURMCluster(cores=2,processes=1,memory="47GB",walltime='02:00:00')
client = Client(cluster)
cluster.scale(cores=24)
# Out:
# /g/data/v14/tm4888/miniconda3/envs/pangeo_hpc/lib/python3.9/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %%
client
# Out:
# <Client: 'tcp://10.0.128.137:36207' processes=0 threads=0, memory=0 B>

# %% [markdown]
# # load main collections from zarr

# %%
# %%time
ds_TUV = xr.open_zarr('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.ocean.masked.AUSWCPregion.TUV_025deg.zarr',consolidated=True)
# Out:
# CPU times: user 50.4 ms, sys: 4.24 ms, total: 54.7 ms
# Wall time: 63 ms

# %% [markdown]
# # Grid information for ACCESS S2?

# %%
# %%time
ds_S2_Tgrid = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/temp/mo_temp_1990.nc')
# Out:
# CPU times: user 41.3 ms, sys: 11.7 ms, total: 52.9 ms
# Wall time: 54.5 ms

# %% [markdown]
# ## depth weights

# %%
depth_weights = ds_S2_Tgrid.deptht_bounds.diff(dim='ndepth_bounds').squeeze().rename({'deptht':'depth'})
depth_weights.values
# Out:
# distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/v14/tm4888/miniconda3/envs/pangeo_hpc/lib/python3.9/site-packages/distributed/scheduler.py", line 4811, in update_graph
#     plugin.update_graph(
#   File "/g/data/v14/tm4888/miniconda3/envs/pangeo_hpc/lib/python3.9/site-packages/distributed/diagnostics/websocket.py", line 36, in update_graph
#     self.socket.send("update_graph", {"client": client})
#   File "/g/data/v14/tm4888/miniconda3/envs/pangeo_hpc/lib/python3.9/site-packages/distributed/http/scheduler/info.py", line 197, in send
#     self.write_message(data)
#   File "/g/data/v14/tm4888/miniconda3/envs/pangeo_hpc/lib/python3.9/site-packages/tornado/websocket.py", line 337, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# array([  1.0239066,   1.0792834,   1.1481192,   1.2337434,   1.3401852,
#          1.4722052,   1.6352429,   1.8352118,   2.0780945,   2.369277 ,
#          2.712654 ,   3.1096478,   3.5584164,   4.0536633,   4.5873146,
#          5.150135 ,   5.7339096,   6.333458 ,   6.948097 ,   7.582039 ,
#          8.244095 ,   8.946861 ,   9.705849 ,  10.538765 ,  11.465065 ,
#         12.505692 ,  13.683044 ,  15.021072 ,  16.545197 ,  18.282547 ,
#         20.261673 ,  22.512512 ,  25.065903 ,  27.952911 ,  31.204071 ,
#         34.848145 ,  38.910614 ,  43.411926 ,  48.365784 ,  53.776886 ,
#         59.638855 ,  65.93317  ,  72.62689  ,  79.67352  ,  87.01233  ,
#         94.57056  , 102.265564 , 110.00891  , 117.70947  , 125.277954 ,
#        132.63196  , 139.69739  , 146.41333  , 152.73181  , 158.6195   ,
#        164.05664  , 169.03613  , 173.56226  , 177.64746  , 181.31226  ,
#        184.5813   , 187.48242  , 190.04639  , 192.30273  , 194.28223  ,
#        196.01294  , 197.52246  , 198.83594  , 199.97656  , 200.96533  ,
#        201.8208   , 202.56104  , 203.1997   , 203.75098  , 204.22852  ],
#       dtype=float32)

# %%
depth_weights
# Out:
# <xarray.DataArray 'deptht_bounds' (depth: 75)>
# dask.array<getitem, shape=(75,), dtype=float32, chunksize=(75,), chunktype=numpy.ndarray>
# Coordinates:
#   * depth    (depth) float32 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03

# %% [markdown]
# # $\big\Downarrow$ Calculate

# %% [markdown]
# # EKE

# %%
def calc_EKE(u, v, time_name = 'time'):
    '''
    Author1 = {"name": "Thomas Moore", "affiliation": "CSIRO", "email": "thomas.moore@csiro.au", "orcid": "0000-0003-3930-1946"}
    u,v are x and y currents as an xarray data array
    '''
    u_mean = u.mean(time_name)
    v_mean = v.mean(time_name)
    MKE = 0.5*(u_mean**2 + v_mean**2).rename('MKE') # currents
    EKE = ( 0.5 * ((u-u_mean)**2 + (v-v_mean)**2) ).rename('EKE') # eddies
    return EKE, MKE

# %%
# %%time
[EKE, MKE] = calc_EKE(ds_TUV.u, ds_TUV.v, time_name='time')
# Out:
# CPU times: user 52 ms, sys: 2.68 ms, total: 54.6 ms
# Wall time: 52.9 ms

# %% [markdown]
# # U100

# %%
u100 = ds_TUV.u.sel(depth=100,method='nearest')

# %% [markdown]
# # V100

# %%
v100 = ds_TUV.v.sel(depth=100,method='nearest')

# %% [markdown]
# # u100_300

# %% [markdown]
# ## need to use depth weighted mean

# %%
def weighted_ocean_mean(ds,weights=None,dim=None,sel_dict=None):
    """
    weighted_ocean_mean
    Returns: ds_weighted
    Defaults: no spatial and time selection, no weights, no selected dims
    Author: Thomas Moore (based on Dougie Squire code)
    Date created: 11/02/2020

    Assumptions:
    Dataset or Dataarray = ds
    Use:
    Limitations:
    """

    if weights is None:
        return ds.sel(sel_dict).mean(dim)
    else:
        #weights = (0 * da + 1) * weights
        #return (da * weights).sum(dim) / weights.sum(dim)
        return (ds.sel(sel_dict) * weights).sum(dim,skipna=True) / weights.where(ds.sel(sel_dict).notnull()).sum(dim,skipna=True)

# %%
u100_300 = helper.weighted_ocean_mean(ds_TUV.u,weights=depth_weights,dim='depth',sel_dict={'depth':slice(100,300)})

# %% [markdown]
# # v100_300

# %% [markdown]
# ## need to use depth weighted mean

# %%
v100_300 = helper.weighted_ocean_mean(ds_TUV.v,weights=depth_weights,dim='depth',sel_dict={'depth':slice(100,300)})

# %% [markdown]
# # EKE_300

# %% [markdown]
# ## need to account for variable cell thickness without formal integration

# %%
eke300 = (EKE * depth_weights).sel(depth=slice(0,300)).sum('depth',skipna=True)
eke300 = eke300.where(eke300 != 0)

# %% [markdown]
# # EKE_2000

# %% [markdown]
# ## need to account for variable cell thickness without formal integration

# %%
eke2000 = (EKE * depth_weights).sel(depth=slice(0,2000)).sum('depth',skipna=True)
eke2000 = eke2000.where(eke2000 != 0)

# %% [markdown]
# # Merge added calculated variables

# %%
ds_TUV['u100'] = u100
ds_TUV['v100'] = v100
ds_TUV['u100_300'] = u100_300
ds_TUV['v100_300'] = v100_300
ds_TUV['eke300'] = eke300
ds_TUV['eke2000'] = eke2000

# %% [markdown]
# # Drop 3D u & v as well as depth coordinate

# %%
ds_TUV = ds_TUV.drop_vars(['u','v'])
ds_TUV = ds_TUV.drop_dims(['depth'])

# %%
ds_TUV.nbytes/1e9
# Out:
# 9.74180986

# %% [markdown]
# # Write out single zarr collection

# %%
# %%time
ds_TUV.to_zarr('/g/data/v14/tm4888/data/ACCESS-S2/accessS2.RA.ocean.masked.AUSWCPregion.ETBFvars.zarr',consolidated=True)
# Out:
# distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/v14/tm4888/miniconda3/envs/pangeo_hpc/lib/python3.9/site-packages/distributed/scheduler.py", line 4811, in update_graph
#     plugin.update_graph(
#   File "/g/data/v14/tm4888/miniconda3/envs/pangeo_hpc/lib/python3.9/site-packages/distributed/diagnostics/websocket.py", line 36, in update_graph
#     self.socket.send("update_graph", {"client": client})
#   File "/g/data/v14/tm4888/miniconda3/envs/pangeo_hpc/lib/python3.9/site-packages/distributed/http/scheduler/info.py", line 197, in send
#     self.write_message(data)
#   File "/g/data/v14/tm4888/miniconda3/envs/pangeo_hpc/lib/python3.9/site-packages/tornado/websocket.py", line 337, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# CPU times: user 58.7 s, sys: 5.31 s, total: 1min 3s
# Wall time: 1min 33s

# %% [markdown]
# # $ The\ End$

# %% [markdown]
# # Break glass in case of emergency
# # $\Downarrow$

# %%
client.restart()

# %%
client.shutdown()
# Out:
# distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# _GatheringFuture exception was never retrieved
# future: <_GatheringFuture finished exception=CancelledError()>
# asyncio.exceptions.CancelledError

# %%
client.restart()

# %%
# %%time
ds_SSS_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/sss/mo_sss_*.nc',parallel=True,preprocess=drop_not_in_2015)

# %%
# %%time
ds_mld1_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/mld1/mo_mld1_*.nc',parallel=True,preprocess=drop_not_in_2015)

# %%
# %%time
ds_mld2_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/mld2/mo_mld2_*.nc',parallel=True,preprocess=drop_not_in_2015)

# %%
# %%time
ds_D20_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/d20/mo_d20_*.nc',parallel=True,preprocess=drop_not_in_2015)

# %%
# %%time
ds_hc300_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/hc300/mo_hc300_*.nc',parallel=True,preprocess=drop_not_in_2015)

# %%
# %%time
ds_td_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/td/mo_td_*.nc',parallel=True,preprocess=drop_not_in_2015)

# %%
# %%time
ds_temp_1981_2018 = xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/temp/mo_temp_*.nc',parallel=True,preprocess=drop_not_in_2015)

# %%
ds_temp50_1981_2018 = ds_temp_1981_2018.sel(deptht=50,method='nearest').rename({'temp':'temp50'})
ds_temp100_1981_2018 = ds_temp_1981_2018.sel(deptht=100,method='nearest').rename({'temp':'temp100'})
ds_temp200_1981_2018 = ds_temp_1981_2018.sel(deptht=200,method='nearest').rename({'temp':'temp200'})
ds_temp500_1981_2018 = ds_temp_1981_2018.sel(deptht=500,method='nearest').rename({'temp':'temp500'})

# %%
ds_ACCESS_S2_RA_ocean = xr.merge([ds_temp50_1981_2018.drop('deptht'),
                                  ds_temp100_1981_2018.drop('deptht'),
                                  ds_temp200_1981_2018.drop('deptht'),
                                  ds_temp500_1981_2018.drop('deptht'),
                                  ds_SST_1981_2018.squeeze(),
                                  ds_SSS_1981_2018.squeeze(),
                                  ds_mld1_1981_2018,
                                  ds_mld2_1981_2018,
                                  ds_D20_1981_2018,
                                  ds_hc300_1981_2018,
                                  ds_td_1981_2018
                                 ],compat='override')
ds_ACCESS_S2_RA_ocean = ds_ACCESS_S2_RA_ocean.drop('time_counter_bnds')
ds_ACCESS_S2_RA_ocean = ds_ACCESS_S2_RA_ocean.drop('deptht')
ds_ACCESS_S2_RA_ocean

# %% [markdown]
# ## add back in key metadata

# %%
areat = (xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/sst/mo_sst_2016.nc',parallel=True)).areat.to_dataset()
areau = (xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/u/mo_u_2016.nc',parallel=True)).areau.to_dataset()
areav = (xr.open_mfdataset('/g/data/ux62/access-s2/reanalysis/ocean/v/mo_v_2016.nc',parallel=True)).areav.to_dataset()
